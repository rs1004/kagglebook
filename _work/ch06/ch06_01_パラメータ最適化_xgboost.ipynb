# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 学習データ・評価データの準備

# %%
# train_xは学習データ、train_yは目的変数、test_xはテストデータ
# pandasのDataFrame, Seriesで保持します。（numpyのarrayで保持することもあります）

train = pd.read_csv('../../input/sample-data/train_preprocessed.csv')
train_x = train.drop(['target'], axis=1)
train_y = train['target']

# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=71)
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# %% [markdown]
# ## 評価関数定義

# %%
import xgboost as xgb
from sklearn.metrics import log_loss

# %%
def score(opt_params):
    params = {
        'booster': 'gbtree',
        'objective': 'binary:logistic',
        'eta': 0.1,
        'gamma': 0.0,
        'alpha': 0.0,
        'lambda': 1.0,
        'min_child_weight': 1,
        'max_depth': 5,
        'subsample': 0.8,
        'colsample_bytree': 0.8,
        'random_state': 71,
    }
    params.update(opt_params)

    # 学習
    num_round = 10
    dtrain = xgb.DMatrix(tr_x, label=tr_y)
    dvalid = xgb.DMatrix(va_x, label=va_y)
    watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
    model = xgb.train(params, dtrain, num_round, evals=watchlist)

    va_pred = model.predict(dvalid)
    score = log_loss(va_y, va_pred)
    print(f'params: {params}, logloss: {score:.4f}')

    # 情報を記録しておく
    history.append((params, score))

    return {'loss': score, 'status': 'ok'}

# %% [markdown]
# ## 探索実行

# %%
from hyperopt import fmin, tpe, hp, Trials
from hyperopt.pyll.base import scope

# %%
param_space = {
    'min_child_weight': hp.loguniform('min_child_weight', np.log(0.1), np.log(10)),
    'max_depth': scope.int(hp.quniform('max_depth', 3, 9, 1)),
#     'subsample': hp.quniform('subsample', 0.6, 0.95, 0.05),
    'colsample_bytree': hp.quniform('subsample', 0.6, 0.95, 0.05),
    'gamma': hp.loguniform('gamma', np.log(1e-8), np.log(1.0)),
    'alpha' : hp.loguniform('alpha', np.log(1e-8), np.log(1.0)),
    'lambda' : hp.loguniform('lambda', np.log(1e-6), np.log(10.0)),
}

# hyperoptによるパラメータ探索の実行
max_evals = 10
trials = Trials()
history = []
fmin(score, param_space, algo=tpe.suggest, trials=trials, max_evals=max_evals)

# 記録した情報からパラメータとスコアを出力する
# （trialsからも情報が取得できるが、パラメータの取得がやや行いづらいため）
history = sorted(history, key=lambda tpl: tpl[1])
best = history[0]
# Out:
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=5
# [0]	train-error:0.168	eval-error:0.1804
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [1]	train-error:0.1368	eval-error:0.1544
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [2]	train-error:0.1344	eval-error:0.1524
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [3]	train-error:0.128533	eval-error:0.1488
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=5
# [4]	train-error:0.1248	eval-error:0.1428
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=5
# [5]	train-error:0.125333	eval-error:0.1424
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [6]	train-error:0.121867	eval-error:0.1424
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [7]	train-error:0.122533	eval-error:0.144
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=5
# [8]	train-error:0.118	eval-error:0.1424
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=5
# [9]	train-error:0.117733	eval-error:0.1412
# params: {'booster': 'gbtree', 'objective': 'binary:logistic', 'eta': 0.1, 'gamma': 0.00028227614655890377, 'alpha': 1.3675142225058274e-05, 'lambda': 0.39219878449142875, 'min_child_weight': 0.2525458371392585, 'max_depth': 5, 'subsample': 0.8, 'colsample_bytree': 0.75, 'random_state': 71}, logloss: 0.4262
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 0 pruned nodes, max_depth=8
# [0]	train-error:0.148533	eval-error:0.1908
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 22 pruned nodes, max_depth=8
# [1]	train-error:0.097467	eval-error:0.154
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 226 extra nodes, 28 pruned nodes, max_depth=8
# [2]	train-error:0.0968	eval-error:0.146
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 222 extra nodes, 48 pruned nodes, max_depth=8
# [3]	train-error:0.092667	eval-error:0.1436
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 238 extra nodes, 48 pruned nodes, max_depth=8
# [4]	train-error:0.086667	eval-error:0.1392
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 264 extra nodes, 28 pruned nodes, max_depth=8
# [5]	train-error:0.0824	eval-error:0.136
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 272 extra nodes, 48 pruned nodes, max_depth=8
# [6]	train-error:0.076267	eval-error:0.1384
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 276 extra nodes, 38 pruned nodes, max_depth=8
# [7]	train-error:0.072667	eval-error:0.1332
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 238 extra nodes, 42 pruned nodes, max_depth=8
# [8]	train-error:0.072933	eval-error:0.1356
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 338 extra nodes, 42 pruned nodes, max_depth=8
# [9]	train-error:0.068933	eval-error:0.1344
# params: {'booster': 'gbtree', 'objective': 'binary:logistic', 'eta': 0.1, 'gamma': 0.29127849787910304, 'alpha': 0.0001481874408414698, 'lambda': 0.003860563166108255, 'min_child_weight': 0.4284492746030479, 'max_depth': 8, 'subsample': 0.8, 'colsample_bytree': 0.8, 'random_state': 71}, logloss: 0.4052
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [0]	train-error:0.164533	eval-error:0.1804
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [1]	train-error:0.151867	eval-error:0.1728
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [2]	train-error:0.139867	eval-error:0.154
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [3]	train-error:0.1356	eval-error:0.154
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [4]	train-error:0.125733	eval-error:0.1536
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [5]	train-error:0.123067	eval-error:0.1504
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [6]	train-error:0.118	eval-error:0.1476
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [7]	train-error:0.116	eval-error:0.1488
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [8]	train-error:0.1152	eval-error:0.1444
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [9]	train-error:0.115067	eval-error:0.1432
# params: {'booster': 'gbtree', 'objective': 'binary:logistic', 'eta': 0.1, 'gamma': 1.2666874341719118e-07, 'alpha': 0.008418588989093444, 'lambda': 2.5587477220972863e-05, 'min_child_weight': 5.592730783812346, 'max_depth': 6, 'subsample': 0.8, 'colsample_bytree': 0.7000000000000001, 'random_state': 71}, logloss: 0.4227
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [0]	train-error:0.1464	eval-error:0.1716
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [1]	train-error:0.123467	eval-error:0.1456
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [2]	train-error:0.1176	eval-error:0.1472
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [3]	train-error:0.114267	eval-error:0.1468
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [4]	train-error:0.11	eval-error:0.14
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [5]	train-error:0.108533	eval-error:0.1396
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [6]	train-error:0.106	eval-error:0.14
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [7]	train-error:0.1	eval-error:0.1384
# [08:09:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [8]	train-error:0.1008	eval-error:0.1412
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=6
# [9]	train-error:0.0984	eval-error:0.14
# params: {'booster': 'gbtree', 'objective': 'binary:logistic', 'eta': 0.1, 'gamma': 7.143123070138008e-06, 'alpha': 1.1091021009724416e-07, 'lambda': 0.13967417937385992, 'min_child_weight': 0.828123226504951, 'max_depth': 6, 'subsample': 0.8, 'colsample_bytree': 0.8500000000000001, 'random_state': 71}, logloss: 0.4142
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [0]	train-error:0.1644	eval-error:0.182
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [1]	train-error:0.140267	eval-error:0.154
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [2]	train-error:0.130133	eval-error:0.1492
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [3]	train-error:0.125467	eval-error:0.148
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [4]	train-error:0.124133	eval-error:0.1456
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [5]	train-error:0.124667	eval-error:0.1444
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [6]	train-error:0.1232	eval-error:0.1444
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [7]	train-error:0.1228	eval-error:0.144
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [8]	train-error:0.119867	eval-error:0.1416
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=6
# [9]	train-error:0.1188	eval-error:0.1392
# params: {'booster': 'gbtree', 'objective': 'binary:logistic', 'eta': 0.1, 'gamma': 0.01310684357856094, 'alpha': 0.000721038535978241, 'lambda': 1.833248154594146, 'min_child_weight': 4.607787262552185, 'max_depth': 6, 'subsample': 0.8, 'colsample_bytree': 0.8, 'random_state': 71}, logloss: 0.4218
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=8
# [0]	train-error:0.127867	eval-error:0.152
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=8
# [1]	train-error:0.1208	eval-error:0.1416
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=8
# [2]	train-error:0.1132	eval-error:0.1368
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=8
# [3]	train-error:0.1108	eval-error:0.1368
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 2 pruned nodes, max_depth=8
# [4]	train-error:0.110133	eval-error:0.138
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=8
# [5]	train-error:0.106267	eval-error:0.1348
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 0 pruned nodes, max_depth=8
# [6]	train-error:0.105333	eval-error:0.136
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 0 pruned nodes, max_depth=8
# [7]	train-error:0.1028	eval-error:0.13
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=8
# [8]	train-error:0.102133	eval-error:0.1336
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=8
# [9]	train-error:0.0988	eval-error:0.1268
# params: {'booster': 'gbtree', 'objective': 'binary:logistic', 'eta': 0.1, 'gamma': 0.0412844360022436, 'alpha': 0.18769662886783933, 'lambda': 4.951156091154497e-06, 'min_child_weight': 4.353762802618278, 'max_depth': 8, 'subsample': 0.8, 'colsample_bytree': 0.9, 'random_state': 71}, logloss: 0.4012
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 2 pruned nodes, max_depth=7
# [0]	train-error:0.1204	eval-error:0.1476
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 0 pruned nodes, max_depth=7
# [1]	train-error:0.1076	eval-error:0.1416
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 2 pruned nodes, max_depth=7
# [2]	train-error:0.106933	eval-error:0.1428
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 0 pruned nodes, max_depth=7
# [3]	train-error:0.101867	eval-error:0.1404
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 0 pruned nodes, max_depth=7
# [4]	train-error:0.095867	eval-error:0.1404
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 0 pruned nodes, max_depth=7
# [5]	train-error:0.092933	eval-error:0.1372
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 2 pruned nodes, max_depth=7
# [6]	train-error:0.089333	eval-error:0.1384
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 0 pruned nodes, max_depth=7
# [7]	train-error:0.088	eval-error:0.1344
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 200 extra nodes, 2 pruned nodes, max_depth=7
# [8]	train-error:0.084267	eval-error:0.1364
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 0 pruned nodes, max_depth=7
# [9]	train-error:0.084133	eval-error:0.128
# params: {'booster': 'gbtree', 'objective': 'binary:logistic', 'eta': 0.1, 'gamma': 0.11274857208519581, 'alpha': 0.5398021196158149, 'lambda': 0.0005378899382060495, 'min_child_weight': 0.17004986857693843, 'max_depth': 7, 'subsample': 0.8, 'colsample_bytree': 0.9, 'random_state': 71}, logloss: 0.4034
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [0]	train-error:0.162533	eval-error:0.168
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [1]	train-error:0.162533	eval-error:0.168
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [2]	train-error:0.1648	eval-error:0.1684
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [3]	train-error:0.162133	eval-error:0.1672
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [4]	train-error:0.161067	eval-error:0.1672
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [5]	train-error:0.164	eval-error:0.168
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [6]	train-error:0.159333	eval-error:0.1656
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [7]	train-error:0.157733	eval-error:0.1664
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [8]	train-error:0.157733	eval-error:0.1692
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=3
# [9]	train-error:0.155867	eval-error:0.1664
# params: {'booster': 'gbtree', 'objective': 'binary:logistic', 'eta': 0.1, 'gamma': 0.020007173465552905, 'alpha': 3.7528466338228064e-08, 'lambda': 0.005097307395873973, 'min_child_weight': 0.20403084504912047, 'max_depth': 3, 'subsample': 0.8, 'colsample_bytree': 0.9500000000000001, 'random_state': 71}, logloss: 0.4519
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [0]	train-error:0.1532	eval-error:0.1624
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [1]	train-error:0.146933	eval-error:0.1636
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [2]	train-error:0.144	eval-error:0.16
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [3]	train-error:0.147067	eval-error:0.1624
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [4]	train-error:0.144133	eval-error:0.16
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [5]	train-error:0.1432	eval-error:0.1596
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [6]	train-error:0.144	eval-error:0.1592
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [7]	train-error:0.1444	eval-error:0.1608
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=4
# [8]	train-error:0.1408	eval-error:0.1588
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=4
# [9]	train-error:0.140267	eval-error:0.1576
# params: {'booster': 'gbtree', 'objective': 'binary:logistic', 'eta': 0.1, 'gamma': 0.1146908270012884, 'alpha': 1.4696704250916958e-08, 'lambda': 1.8041283920976696, 'min_child_weight': 0.31113966098945056, 'max_depth': 4, 'subsample': 0.8, 'colsample_bytree': 0.9, 'random_state': 71}, logloss: 0.4384
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=7
# [0]	train-error:0.172533	eval-error:0.1924
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=7
# [1]	train-error:0.172	eval-error:0.1872
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=7
# [2]	train-error:0.164533	eval-error:0.1836
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=7
# [3]	train-error:0.159467	eval-error:0.1756
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=7
# [4]	train-error:0.148667	eval-error:0.1708
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=7
# [5]	train-error:0.141333	eval-error:0.1648
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=7
# [6]	train-error:0.137733	eval-error:0.1604
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=7
# [7]	train-error:0.139467	eval-error:0.162
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 2 pruned nodes, max_depth=7
# [8]	train-error:0.134533	eval-error:0.1596
# [08:09:25] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=7
# [9]	train-error:0.134933	eval-error:0.1596
# params: {'booster': 'gbtree', 'objective': 'binary:logistic', 'eta': 0.1, 'gamma': 0.15815967873277753, 'alpha': 0.18772670595232036, 'lambda': 8.422921599098753, 'min_child_weight': 8.490379672002138, 'max_depth': 7, 'subsample': 0.8, 'colsample_bytree': 0.6000000000000001, 'random_state': 71}, logloss: 0.4370

# %%
print(f'best params:{best[0]}, score:{best[1]:.4f}')
# Out:
# best params:{'booster': 'gbtree', 'objective': 'binary:logistic', 'eta': 0.1, 'gamma': 0.0412844360022436, 'alpha': 0.18769662886783933, 'lambda': 4.951156091154497e-06, 'min_child_weight': 4.353762802618278, 'max_depth': 8, 'subsample': 0.8, 'colsample_bytree': 0.9, 'random_state': 71}, score:0.4012

# %% [markdown]
# => tr_xなどをグローバル変数として扱っていることに気持ち悪さを感じるが、基本の型は上記のような感じ。
